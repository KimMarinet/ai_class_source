# %%
import requests
from bs4 import BeautifulSoup as bs
html = requests.get("https://news.naver.com/").text
soup = bs(html, 'html.parser')
body = soup.select_one("body")
text = body.get_text().strip().replace("\n", "")
stopwords = ['본문', '바로가기', 'NAVER'] #불용어

text
# Out:
# '본문 바로가기NAVER뉴스엔터스포츠날씨프리미엄대선검색언론사별정치경제사회생활/문화IT/과학세계랭킹신문보기오피니언TV팩트체크알고리즘 안내정정보도 모음콘텐츠6.4(수)전체 언론사뉴스스탠드라이브러리언론사편집기자                                            연재                                                            구독설정                                속보이주호, 이재명 대통령에게 국무위원 전체 사의 표명대전일보내용작성전시진핑, 이재명 대통령에게 전화 걸어 “관계 발전 매우 중시”경향신문李대통령 공약 \'대법관 증원법\' 법사소위 통과…16명 늘려 30명중앙일보내용작성전이 대통령 공약 \'대법관 증원법\' 법사소위 통과…16명 늘려 30명SBS내용작성전\'대법관 증원법\' 법사위 소위 통과…16명 늘려 30명아시아경제내용작성전이주호 부총리, 李대통령에게 전체 국무위원 사의 표명서울신문내용작성전이주호, 이재명 대통령에게 전체 국무위원 사의 표명경기일보내용작성전김문수 “국민 대부분 원치 않던 이재명 대통령 취임”세계일보이주호, 이재명 대통령에게 전체 국무위원 사의 표명조선비즈내용작성전이주호 전 대행, 李대통령에게 전체 국무위원 사의 표명국제신문내용작성전이주호, 이재명 대통령에게 전체 국무위원 사의 표명한경비즈니스내용작성전이주호, 이재명 대통령에게 전체 국무위원 사의 표명서울경제내용작성전시진핑 "이재명 대통령 당선 축하…양국 관계 고도로 중시" 축전 보내디지털타임스시진핑 “양국 관계 발전 고도로 중시…이재명 대통령 당선 축하”문화일보속보 닫기경기일보06월 04일 16:37구독이재명 대통령, 정당 대표 오찬서 "천하람·김용태 위원장님 제가 잘 모시겠다""첫눈에 반한 사람은 김혜경"… 소개팅서 만난 \'운명의 상대\', 평생의 지원군으로이재명 정부 첫 인사… 국무총리 김민석·비서실장 강훈식·국정원장 이종석 지명조국, 옥중서신서 "정권교체는 국민 승리"채널A06월 04일 15:59구독[단독]李 대통령, 6개월 내 용산 대통령실→청와대로 이전 추진李 “당장 시행할 경제회생정책 필요”…추경 편성 시사국무총리 김민석, 국정원장 이종석, 비서실장 강훈식 지명이재명 사저 앞 태극기 행렬…강아지의 돌발 행동?! [현장영상]JTBC06월 04일 16:37구독영상이재명 정부 첫 인사 발표…국무총리 후보자 김민석 지명[단독]\'윤 경호처 강경파\' 여전한 영향력?...오늘 대통령 취임식서 22경찰경호대 배제\'장원영 비방\' 탈덕수용소, 소속사에 5000만원 배상 판결득표율 10% 못 넘긴 이준석…선거비 전액 날려매일경제06월 04일 16:38구독李 대통령 “용산 사무실 꼭 무덤같아...공무원들에 대통령실 원대복귀 명령할 것”“부채 탕감 해준다던데”…막 오른 이재명 정부, 소상공인 숨통 트이나[단독] “입주민들 옥상 보자마자 충격 받아”…서울 아파트 꼭대기에 설치된 군사시설“연락 할 때마다 거절했다”…무참히 살해당한 17세 파키스탄女의 정체농민신문06월 04일 15:53구독국무총리에 김민석, 국정원장에 이종석 내정…이 대통령, 첫 인사 발표이재명 대통령 “정의로운 통합정부, 유연한 실용정부” 약속이재명 대통령·김문수는 받고 이준석은 못 받는 ‘이것’李대통령의 첫 오찬 메뉴는 OOO…여야 대표와 “양보와 타협” 강조미디어오늘06월 04일 16:26구독뉴욕타임스 "이재명, 尹 비상 계엄의 가장 큰 정치적 수혜자""광장이 열렸는데 그 결과가 진보정치의 종말일 순 없었다"배현진 "웃으며 투표한 尹 보며 난처하고 고통스러웠다"이재명 정부 첫 대통령실 대변인에 강유정 의원SBS Biz06월 04일 16:33구독[속보] 이주호, 이재명 대통령에게 전체 국무위원 사의 표명연봉 2.4억에 전담 경호·전용기·주치의…대통령 의전은?이재명 \'부산 이전\' 공약에…HMM 노조 "추진시 강력투쟁"금감원, \'보험 끼워팔기\' 흥국화재에 제재…과태료 1억원·기관주의SBS06월 04일 16:32구독[속보] 이주호, 이재명 대통령에게 전체 국무위원 사의 표명이재명 대통령, 정부 첫 인사 발표…김민석 국무총리 지명김용태 "이 대통령 오찬서 \'법원조직법만 처리할 수도\' 얘기"육해공 각군 총장, 이재명 대통령 취임선서 초청 명단서 빠져코리아헤럴드06월 04일 15:12구독\'President for all\': Lee vows unityWhat Lee pledged to do as presidentKospi hits year-high on postelection optimismPeople Power Party scrambles in aftermath of election뉴스타파06월 02일 20:45구독또다른 \'자손군\' 댓글팀 \'민주당해산운동본부 트루스코리아\'...100만원씩 포상금[목소리 프로젝트 : 에너지] 기후위기 돌파구, 누가 진짜 그린 리더인가?[KINN] ‘한덕수 대망론’, 언론개혁 절실함을 보여주다리박스쿨 \'댓글부대 단장\'이 아이들 상대 \'역사 강의\'서울경제06월 04일 16:29구독“전쟁같은 정치 없길”…李, 정당 대표 등과 ‘비빔밥’ 오찬[이재명 시대][속보] 이주호, 이재명 대통령에게 전체 국무위원 사의 표명국내외 코인 전문가 총집결…韓 가상자산 관심 후끈 [비트코인 서울 2025]이재명·김문수는 1155억 받는데..\'이대남\' 몰표 이준석은 한 푼도 못 받는다한겨레2106월 04일 15:59구독이재명 정부 첫 인사, 총리 후보자 김민석·국정원장 이종석 지명…비서실장 강훈식 임명이재명 대통령 취임 “장갑차·자동소총에 파괴된 민주주의 일으켜 세울 시간”“나는 계몽되었다”고 말하는 한국 극우, 외래종 아닌 자생종그 혁명가는 왜 일제의 밀정이 되었나파이낸셜뉴스06월 04일 16:35구독李 임기 첫날 \'대법관 증원법\' 추진…사법개혁 속도 붙나[속보]이주호, 이재명 대통령에게 전체 국무위원 사의 표명"선거 특수도 없어요"…깊어지는 자영업자들의 \'한숨\'‘尹 변호’ 김계리 “이재명, 빚잔치 말고 나라 생각하는 대통령되길”주간조선06월 04일 15:51구독이재명 정부 초대 국정원장 이종석, 안보실장 위성락이재명 대통령 받고 있는 5개 형사재판의 향방은?이재명 취임사 "박정희 정책도, 김대중 정책도 구별없이 쓰겠다""홍준표, 남의 당에 관심 꺼라"... 박근혜 최측근 유영하의 분노연합뉴스TV06월 04일 16:37구독[속보] \'대법관 증원법\', 민주 주도로 법사소위 통과…16명 늘려 30명이 대통령 "당장 할 수 있는 경제회생 정책 최대한 점검"이 대통령, 총리 후보자로 김민석 지명…비서실장 강훈식\'거대 여당\' 된 민주…국민의힘은 \'쇄신론\' 분출헬스조선06월 04일 16:23구독‘6kg 감량’ 맹승지, 매일 하는 루틴… “일어나자마자 ‘이것’부터 마셔”“‘이곳’ 털 엉키며 통증, 탈모까지” 충격… 마라톤 중이던 60대 男, 무슨 일?"라미란, 살 또 빠졌네?"… 14kg 감량 비결은 \'이것\' 섭취 줄인 것“다이어트 중, 6kg 감량” 이국주, ‘이 음식’으로 뺐다던데… 뭘까?지디넷코리아06월 04일 16:35구독李, 총리 김민석 의원·국정원장 이종석 전 장관 지명"아이폰17 디스플레이, 120Hz 지원…프로모션 기능은 뺀다"불길 잡혔던 \'플랫폼법\'...새 정부서 불씨 살까화해, ‘화해위크’ 개최⋯인기 뷰티 최대 88% 할인YTN06월 04일 16:09구독영상"모두의 대통령 되겠다"...국민 대통합 천명국무총리 김민석·비서실장 강훈식...이 대통령 직접 인선 발표경제도 외교도 \'실용\' 강조...\'비상경제대응TF\' 가동필리핀 HIV 감염 급증...비상사태 선포 가능성프레시안06월 04일 16:35구독정세현 "이재명, 특검 열어 \'한덕수가 미국에 한 약속\' 알아내야"백악관, 이재명 당선에 축하 메시지도 없이 "중국 영향력 우려"…황당한 논평대선 패배로 \'야당\'된 국민의힘, 앞날은?\'이재명 정부\' 초대 총리 김민석, 비서실장 강훈식 발탁노컷뉴스06월 04일 16:36구독김민석 \'일인지하\'까지…18년 암흑기 겪고 \'화려한 부활\'이재명 정부 첫날 코스피 2%대 상승…연중 최고李 대통령 취임날 \'대법관 증원법\' 심사,  ...

# %%
# konlpy : 한국어 형태소 분석기
# !pip install konlpy
# Out:
# Collecting konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl.metadata (1.9 kB)
# Collecting JPype1>=0.7.0 (from konlpy)
#   Downloading jpype1-1.5.2-cp312-cp312-win_amd64.whl.metadata (5.0 kB)
# Collecting lxml>=4.1.0 (from konlpy)
#   Downloading lxml-5.4.0-cp312-cp312-win_amd64.whl.metadata (3.6 kB)
# Collecting numpy>=1.6 (from konlpy)
#   Downloading numpy-2.2.6-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: packaging in c:\users\admin\desktop\김문수2\ai_class_source\08 데이터 분석을 위한 python\source\basic\lib\site-packages (from JPype1>=0.7.0->konlpy) (25.0)
# Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#    ---------------------------------------- 0.0/19.4 MB ? eta -:--:--
#    --------- ------------------------------ 4.7/19.4 MB 23.7 MB/s eta 0:00:01
#    ------------------------- -------------- 12.3/19.4 MB 30.8 MB/s eta 0:00:01
#    ---------------------------------------  19.4/19.4 MB 34.0 MB/s eta 0:00:01
#    ---------------------------------------- 19.4/19.4 MB 29.9 MB/s eta 0:00:00
# Downloading jpype1-1.5.2-cp312-cp312-win_amd64.whl (356 kB)
# Downloading lxml-5.4.0-cp312-cp312-win_amd64.whl (3.8 MB)
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 3.8/3.8 MB 37.8 MB/s eta 0:00:00
# Downloading numpy-2.2.6-cp312-cp312-win_amd64.whl (12.6 MB)
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ----------------------------------- ---- 11.3/12.6 MB 50.3 MB/s eta 0:00:01
#    ---------------------------------------- 12.6/12.6 MB 44.0 MB/s eta 0:00:00
# Installing collected packages: numpy, lxml, JPype1, konlpy
# Successfully installed JPype1-1.5.2 konlpy-0.6.0 lxml-5.4.0 numpy-2.2.6
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from konlpy.tag import Okt
okt = Okt()
# Out:
# ---------------------------------------------------------------------------
# SystemError                               Traceback (most recent call last)
# Cell In[6], line 2
#       1 from konlpy.tag import Okt
# ----> 2 okt = Okt()
#
# File c:\Users\admin\Desktop\김문수2\ai_class_source\08 데이터 분석을 위한 python\source\basic\Lib\site-packages\konlpy\tag\_okt.py:51, in Okt.__init__(self, jvmpath, max_heap_size)
#      49 def __init__(self, jvmpath=None, max_heap_size=1024):
#      50     if not jpype.isJVMStarted():
# ---> 51         jvm.init_jvm(jvmpath, max_heap_size)
#      53     oktJavaPackage = jpype.JPackage('kr.lucypark.okt')
#      54     OktInterfaceJavaClass = oktJavaPackage.OktInterface
#
# File c:\Users\admin\Desktop\김문수2\ai_class_source\08 데이터 분석을 위한 python\source\basic\Lib\site-packages\konlpy\jvm.py:64, in init_jvm(jvmpath, max_heap_size)
#      61     jvmpath = '%s/lib/jli/libjli.dylib' % jvmpath.split('/lib/')[0]
#      63 if jvmpath:
# ---> 64     jpype.startJVM(jvmpath, '-Dfile.encoding=UTF8',
#      65                             '-ea', '-Xmx{}m'.format(max_heap_size),
#      66                             classpath=classpath,
#      67                             convertStrings=True)
#      68 else:
#      69     raise ValueError("Please specify the JVM path.")
#
# File c:\Users\admin\Desktop\김문수2\ai_class_source\08 데이터 분석을 위한 python\source\basic\Lib\site-packages\jpype\_core.py:357, in startJVM(jvmpath, classpath, ignoreUnrecognized, convertStrings, interrupt, *jvmargs)
#     355 prior = [locale.getlocale(i) for i in categories]
#     356 # Start the JVM
# --> 357 _jpype.startup(jvmpath, tuple(jvm_args + extra_jvm_args),
#     358                ignoreUnrecognized, convertStrings, interrupt, tmp)
#     359 # Collect required resources for operation
#     360 initializeResources()
#
# SystemError: java.lang.UnsatisfiedLinkError: C:\Users\admin\Desktop: Can't find dependent libraries

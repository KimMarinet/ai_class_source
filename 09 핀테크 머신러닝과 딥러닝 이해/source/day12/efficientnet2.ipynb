# %%
#pip install tensorflow-hub
# Out:
# Collecting tensorflow-hub
#   Downloading tensorflow_hub-0.16.1-py2.py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: numpy>=1.12.0 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow-hub) (1.26.4)
# Requirement already satisfied: protobuf>=3.19.6 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow-hub) (4.25.8)
# Collecting tf-keras>=2.14.1 (from tensorflow-hub)
#   Downloading tf_keras-2.19.0-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: tensorflow<2.20,>=2.19 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tf-keras>=2.14.1->tensorflow-hub) (2.19.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (2.3.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (3.4.0)
# Requirement already satisfied: packaging in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (25.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (2.32.4)
# Requirement already satisfied: setuptools in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (4.14.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (1.73.0)
# Collecting tensorboard~=2.19.0 (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub)
#   Using cached tensorboard-2.19.0-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: keras>=3.5.0 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (3.10.0)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (3.14.0)
# Collecting ml-dtypes<1.0.0,>=0.5.1 (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub)
#   Using cached ml_dtypes-0.5.1-cp312-cp312-win_amd64.whl.metadata (22 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (2025.6.15)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorboard~=2.19.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (3.8.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorboard~=2.19.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorboard~=2.19.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (3.1.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from astunparse>=1.6.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (0.45.1)
# Requirement already satisfied: rich in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (14.0.0)
# Requirement already satisfied: namex in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (0.1.0)
# Requirement already satisfied: optree in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from rich->keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from rich->keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (0.1.2)
# Downloading tensorflow_hub-0.16.1-py2.py3-none-any.whl (30 kB)
# Downloading tf_keras-2.19.0-py3-none-any.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 1.7/1.7 MB 23.6 MB/s eta 0:00:00
# Using cached ml_dtypes-0.5.1-cp312-cp312-win_amd64.whl (210 kB)
# Using cached tensorboard-2.19.0-py3-none-any.whl (5.5 MB)
# Installing collected packages: ml-dtypes, tensorboard, tf-keras, tensorflow-hub
#
#   Attempting uninstall: ml-dtypes
#
#     Found existing installation: ml-dtypes 0.4.1
#
#     Uninstalling ml-dtypes-0.4.1:
#
#       Successfully uninstalled ml-dtypes-0.4.1
#
#   Attempting uninstall: tensorboard
#
#     Found existing installation: tensorboard 2.17.1
#
#    ---------- ----------------------------- 1/4 [tensorboard]
#     Uninstalling tensorboard-2.17.1:
#    ---------- ----------------------------- 1/4 [tensorboard]
#       Successfully uninstalled tensorboard-2.17.1
#    ---------- ----------------------------- 1/4 [tensorboard]
#    ---------- ----------------------------- 1/4 [tensorboard]
#    ---------- ----------------------------- 1/4 [tensorboard]
#    ---------- ----------------------------- 1/4 [tensorboard]
#    ---------- ----------------------------- 1/4 [tensorboard]
#    ---------- ----------------------------- 1/4 [tensorboard]
#    ---------- ----------------------------- 1/4 [tensorboard]
#    ---------- ----------------------------- 1/4 [tensorboard]
#    ---------- ----------------------------- 1/4 [tensorboard]
#    ---------- ----------------------------- 1/4 [tensorboard]
#    ---------- ----------------------------- 1/4 [tensorboard]
#    ---------- ----------------------------- 1/4 [tensorboard]
#    ---------- ----------------------------- 1/4 [tensorboard]
#    ---------- ----------------------------- 1/4 [tensorboard]
#    ---------- ----------------------------- 1/4 [tensorboard]
#    ---------- ----------------------------- 1/4 [tensorboard]
#    ---------- ----------------------------- 1/4 [tensorboard]
#    -------------------- ------------------- 2/4 [tf-keras]
#    -------------------- ------------------- 2/4 [tf-keras]
#    -------------------- ------------------- 2/4 [tf-keras]
#    -------------------- ------------------- 2/4 [tf-keras]
#    -------------------- ------------------- 2/4 [tf-keras]
#    -------------------- ------------------- 2/4 [tf-keras]
#    -------------------- ------------------- 2/4 [tf-keras]
#    -------------------- ------------------- 2/4 [tf-keras]
#    -------------------- ------------------- 2/4 [tf-keras]
#    -------------------- ------------------- 2/4 [tf-keras]
#    -------------------- ------------------- 2/4 [tf-keras]
#    -------------------- ------------------- 2/4 [tf-keras]
#    -------------------- ------------------- 2/4 [tf-keras]
#    -------------------- ------------------- 2/4 [tf-keras]
#    -------------------- ------------------- 2/4 [tf-keras]
#    -------------------- ------------------- 2/4 [tf-keras]
#    -------------------- ------------------- 2/4 [tf-keras]
#    -------------------- ------------------- 2/4 [tf-keras]
#    -------------------- ------------------- 2/4 [tf-keras]
#    -------------------- ------------------- 2/4 [tf-keras]
#    -------------------- ------------------- 2/4 [tf-keras]
#    -------------------- ------------------- 2/4 [tf-keras]
#    -------------------- ------------------- 2/4 [tf-keras]
#    -------------------- ------------------- 2/4 [tf-keras]
#    -------------------- ------------------- 2/4 [tf-keras]
#    -------------------- ------------------- 2/4 [tf-keras]
#    -------------------- ------------------- 2/4 [tf-keras]
#    -------------------- ------------------- 2/4 [tf-keras]
#    -------------------- ------------------- 2/4 [tf-keras]
#    -------------------- ------------------- 2/4 [tf-keras]
#    -------------------- ------------------- 2/4 [tf-keras]
#    -------------------- ------------------- 2/4 [tf-keras]
#    -------------------- ------------------- 2/4 [tf-keras]
#    -------------------- ------------------- 2/4 [tf-keras]
#    -------------------- ------------------- 2/4 [tf-keras]
#    -------------------- ------------------- 2/4 [tf-keras]
#    -------------------- ------------------- 2/4 [tf-keras]
#    -------------------- ------------------- 2/4 [tf-keras]
#    -------------------- ------------------- 2/4 [tf-keras]
#    -------------------- ------------------- 2/4 [tf-keras]
#    -------------------- ------------------- 2/4 [tf-keras]
#    -------------------- ------------------- 2/4 [tf-keras]
#    -------------------- ------------------- 2/4 [tf-keras]
#    -------------------- ------------------- 2/4 [tf-keras]
#    -------------------- ------------------- 2/4 [tf-keras]
#    -------------------- ------------------- 2/4 [tf-keras]
#    -------------------- ------------------- 2/4 [tf-keras]
#    -------------------- ------------------- 2/4 [tf-keras]
#    -------------------- ------------------- 2/4 [tf-keras]
#    -------------------- ------------------- 2/4 [tf-keras]
#    -------------------- ------------------- 2/4 [tf-keras]
#    ------------------------------ --------- 3/4 [tensorflow-hub]
#    ---------------------------------------- 4/4 [tensorflow-hub]
#
# Successfully installed ml-dtypes-0.5.1 tensorboard-2.19.0 tensorflow-hub-0.16.1 tf-keras-2.19.0
# Note: you may need to restart the kernel to use updated packages.

# %%
#pip install tf-keras==2.17.0
# Out:
# Collecting tf-keras==2.17.0
#   Downloading tf_keras-2.17.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting tensorflow<2.18,>=2.17 (from tf-keras==2.17.0)
#   Downloading tensorflow-2.17.1-cp312-cp312-win_amd64.whl.metadata (3.3 kB)
# Collecting tensorflow-intel==2.17.1 (from tensorflow<2.18,>=2.17->tf-keras==2.17.0)
#   Downloading tensorflow_intel-2.17.1-cp312-cp312-win_amd64.whl.metadata (5.0 kB)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow<2.18,>=2.17->tf-keras==2.17.0) (2.3.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow<2.18,>=2.17->tf-keras==2.17.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow<2.18,>=2.17->tf-keras==2.17.0) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow<2.18,>=2.17->tf-keras==2.17.0) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow<2.18,>=2.17->tf-keras==2.17.0) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow<2.18,>=2.17->tf-keras==2.17.0) (3.14.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow<2.18,>=2.17->tf-keras==2.17.0) (18.1.1)
# Collecting ml-dtypes<0.5.0,>=0.3.1 (from tensorflow-intel==2.17.1->tensorflow<2.18,>=2.17->tf-keras==2.17.0)
#   Downloading ml_dtypes-0.4.1-cp312-cp312-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow<2.18,>=2.17->tf-keras==2.17.0) (3.4.0)
# Requirement already satisfied: packaging in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow<2.18,>=2.17->tf-keras==2.17.0) (25.0)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 (from tensorflow-intel==2.17.1->tensorflow<2.18,>=2.17->tf-keras==2.17.0)
#   Downloading protobuf-4.25.8-cp310-abi3-win_amd64.whl.metadata (541 bytes)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow<2.18,>=2.17->tf-keras==2.17.0) (2.32.4)
# Requirement already satisfied: setuptools in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow<2.18,>=2.17->tf-keras==2.17.0) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow<2.18,>=2.17->tf-keras==2.17.0) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow<2.18,>=2.17->tf-keras==2.17.0) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow<2.18,>=2.17->tf-keras==2.17.0) (4.14.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow<2.18,>=2.17->tf-keras==2.17.0) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow<2.18,>=2.17->tf-keras==2.17.0) (1.73.0)
# Collecting tensorboard<2.18,>=2.17 (from tensorflow-intel==2.17.1->tensorflow<2.18,>=2.17->tf-keras==2.17.0)
#   Downloading tensorboard-2.17.1-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: keras>=3.2.0 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow<2.18,>=2.17->tf-keras==2.17.0) (3.10.0)
# Collecting numpy<2.0.0,>=1.26.0 (from tensorflow-intel==2.17.1->tensorflow<2.18,>=2.17->tf-keras==2.17.0)
#   Downloading numpy-1.26.4-cp312-cp312-win_amd64.whl.metadata (61 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.1->tensorflow<2.18,>=2.17->tf-keras==2.17.0) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.1->tensorflow<2.18,>=2.17->tf-keras==2.17.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.1->tensorflow<2.18,>=2.17->tf-keras==2.17.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.1->tensorflow<2.18,>=2.17->tf-keras==2.17.0) (2025.6.15)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.1->tensorflow<2.18,>=2.17->tf-keras==2.17.0) (3.8.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.1->tensorflow<2.18,>=2.17->tf-keras==2.17.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.1->tensorflow<2.18,>=2.17->tf-keras==2.17.0) (3.1.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.17.1->tensorflow<2.18,>=2.17->tf-keras==2.17.0) (0.45.1)
# Requirement already satisfied: rich in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.1->tensorflow<2.18,>=2.17->tf-keras==2.17.0) (14.0.0)
# Requirement already satisfied: namex in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.1->tensorflow<2.18,>=2.17->tf-keras==2.17.0) (0.1.0)
# Requirement already satisfied: optree in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.1->tensorflow<2.18,>=2.17->tf-keras==2.17.0) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow-intel==2.17.1->tensorflow<2.18,>=2.17->tf-keras==2.17.0) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from rich->keras>=3.2.0->tensorflow-intel==2.17.1->tensorflow<2.18,>=2.17->tf-keras==2.17.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from rich->keras>=3.2.0->tensorflow-intel==2.17.1->tensorflow<2.18,>=2.17->tf-keras==2.17.0) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow-intel==2.17.1->tensorflow<2.18,>=2.17->tf-keras==2.17.0) (0.1.2)
# Downloading tf_keras-2.17.0-py3-none-any.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 1.7/1.7 MB 23.2 MB/s eta 0:00:00
# Downloading tensorflow-2.17.1-cp312-cp312-win_amd64.whl (7.5 kB)
# Downloading tensorflow_intel-2.17.1-cp312-cp312-win_amd64.whl (382.4 MB)
#    ---------------------------------------- 0.0/382.4 MB ? eta -:--:--
#     --------------------------------------- 7.6/382.4 MB 39.0 MB/s eta 0:00:10
#    - -------------------------------------- 16.3/382.4 MB 39.4 MB/s eta 0:00:10
#    -- ------------------------------------- 25.2/382.4 MB 39.8 MB/s eta 0:00:09
#    --- ------------------------------------ 33.0/382.4 MB 38.8 MB/s eta 0:00:09
#    ----- ---------------------------------- 48.8/382.4 MB 45.6 MB/s eta 0:00:08
#    ------ --------------------------------- 63.4/382.4 MB 49.9 MB/s eta 0:00:07
#    ------- -------------------------------- 73.1/382.4 MB 49.6 MB/s eta 0:00:07
#    --------- ------------------------------ 86.5/382.4 MB 51.6 MB/s eta 0:00:06
#    ---------- ---------------------------- 104.1/382.4 MB 54.9 MB/s eta 0:00:06
#    ------------ -------------------------- 118.5/382.4 MB 56.9 MB/s eta 0:00:05
#    ------------ -------------------------- 119.5/382.4 MB 51.6 MB/s eta 0:00:06
#    ------------- ------------------------- 129.5/382.4 MB 51.1 MB/s eta 0:00:05
#    -------------- ------------------------ 141.0/382.4 MB 51.2 MB/s eta 0:00:05
#    ---------------- ---------------------- 158.6/382.4 MB 53.6 MB/s eta 0:00:05
#    ----------------- --------------------- 176.2/382.4 MB 55.5 MB/s eta 0:00:04
#    ------------------- ------------------- 192.9/382.4 MB 56.8 MB/s eta 0:00:04
#    --------------------- ----------------- 210.0/382.4 MB 58.1 MB/s eta 0:00:03
#    ----------------------- --------------- 227.3/382.4 MB 59.3 MB/s eta 0:00:03
#    ------------------------ -------------- 243.5/382.4 MB 60.3 MB/s eta 0:00:03
#    -------------------------- ------------ 259.0/382.4 MB 61.3 MB/s eta 0:00:03
#    --------------------------- ----------- 268.4/382.4 MB 60.9 MB/s eta 0:00:02
#    ----------------------------- --------- 285.7/382.4 MB 64.2 MB/s eta 0:00:02
#    ------------------------------ -------- 301.5/382.4 MB 66.5 MB/s eta 0:00:02
#    -------------------------------- ------ 318.0/382.4 MB 66.5 MB/s eta 0:00:01
#    ---------------------------------- ---- 335.5/382.4 MB 69.0 MB/s eta 0:00:01
#    ----------------------------------- --- 348.9/382.4 MB 68.7 MB/s eta 0:00:01
#    ------------------------------------- - 366.0/382.4 MB 68.4 MB/s eta 0:00:01
#    --------------------------------------  382.2/382.4 MB 72.5 MB/s eta 0:00:01
#    --------------------------------------  382.2/382.4 MB 72.5 MB/s eta 0:00:01
#    --------------------------------------  382.2/382.4 MB 72.5 MB/s eta 0:00:01
#    --------------------------------------  382.2/382.4 MB 72.5 MB/s eta 0:00:01
#    --------------------------------------  382.2/382.4 MB 72.5 MB/s eta 0:00:01
#    --------------------------------------  382.2/382.4 MB 72.5 MB/s eta 0:00:01
#    --------------------------------------  382.2/382.4 MB 72.5 MB/s eta 0:00:01
#    --------------------------------------- 382.4/382.4 MB 53.9 MB/s eta 0:00:00
# Downloading ml_dtypes-0.4.1-cp312-cp312-win_amd64.whl (127 kB)
# Downloading numpy-1.26.4-cp312-cp312-win_amd64.whl (15.5 MB)
#    ---------------------------------------- 0.0/15.5 MB ? eta -:--:--
#    ---------------------------------------  15.5/15.5 MB 81.3 MB/s eta 0:00:01
#    ---------------------------------------- 15.5/15.5 MB 61.0 MB/s eta 0:00:00
# Downloading protobuf-4.25.8-cp310-abi3-win_amd64.whl (413 kB)
# Downloading tensorboard-2.17.1-py3-none-any.whl (5.5 MB)
#    ---------------------------------------- 0.0/5.5 MB ? eta -:--:--
#    ---------------------------------------- 5.5/5.5 MB 41.9 MB/s eta 0:00:00
# Installing collected packages: protobuf, numpy, tensorboard, ml-dtypes, tensorflow-intel, tensorflow, tf-keras
#
#   Attempting uninstall: protobuf
#
#     Found existing installation: protobuf 5.29.5
#
#     Uninstalling protobuf-5.29.5:
#
#       Successfully uninstalled protobuf-5.29.5
#
#    ---------------------------------------- 0/7 [protobuf]
#    ---------------------------------------- 0/7 [protobuf]
#    ---------------------------------------- 0/7 [protobuf]
#    ---------------------------------------- 0/7 [protobuf]
#    ---------------------------------------- 0/7 [protobuf]
#    ---------------------------------------- 0/7 [protobuf]
#    ---------------------------------------- 0/7 [protobuf]
#    ---------------------------------------- 0/7 [protobuf]
#    ---------------------------------------- 0/7 [protobuf]
#    ---------------------------------------- 0/7 [protobuf]
#    ---------------------------------------- 0/7 [protobuf]
#    ---------------------------------------- 0/7 [protobuf]
#    ---------------------------------------- 0/7 [protobuf]
#    ---------------------------------------- 0/7 [protobuf]
#    ---------------------------------------- 0/7 [protobuf]
#    ---------------------------------------- 0/7 [protobuf]
#    ---------------------------------------- 0/7 [protobuf]
#    ---------------------------------------- 0/7 [protobuf]
#    ---------------------------------------- 0/7 [protobuf]
#    ---------------------------------------- 0/7 [protobuf]
#    ---------------------------------------- 0/7 [protobuf]
#    ---------------------------------------- 0/7 [protobuf]
#    ---------------------------------------- 0/7 [protobuf]
#   Attempting uninstall: numpy
#    ---------------------------------------- 0/7 [protobuf]
#     Found existing installation: numpy 2.1.3
#    ---------------------------------------- 0/7 [protobuf]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#     Uninstalling numpy-2.1.3:
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#       Successfully uninstalled numpy-2.1.3
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#   Attempting uninstall: tensorboard
#    ----- ---------------------------------- 1/7 [numpy]
#     Found existing installation: tensorboard 2.19.0
#    ----- ---------------------------------- 1/7 [numpy]
#    ----------- ---------------------------- 2/7 [tensorboard]
#     Uninstalling tensorboard-2.19.0:
#    ----------- ---------------------------- 2/7 [tensorboard]
#       Successfully uninstalled tensorboard-2.19.0
#    ----------- ---------------------------- 2/7 [tensorboard]
#    ----------- ---------------------------- 2/7 [tensorboard]
#    ----------- ---------------------------- 2/7 [tensorboard]
#    ----------- ---------------------------- 2/7 [tensorboard]
#    ----------- ---------------------------- 2/7 [tensorboard]
#    ----------- ---------------------------- 2/7 [tensorboard]
#    ----------- ---------------------------- 2/7 [tensorboard]
#    ----------- ---------------------------- 2/7 [tensorboard]
#    ----------- ---------------------------- 2/7 [tensorboard]
#    ----------- ---------------------------- 2/7 [tensorboard]
#    ----------- ---------------------------- 2/7 [tensorboard]
#    ----------- ---------------------------- 2/7 [tensorboard]
#    ----------- ---------------------------- 2/7 [tensorboard]
#    ----------- ---------------------------- 2/7 [tensorboard]
#    ----------- ---------------------------- 2/7 [tensorboard]
#    ----------- ---------------------------- 2/7 [tensorboard]
#    ----------- ---------------------------- 2/7 [tensorboard]
#    ----------- ---------------------------- 2/7 [tensorboard]
#    ----------- ---------------------------- 2/7 [tensorboard]
#    ----------- ---------------------------- 2/7 [tensorboard]
#    ----------- ---------------------------- 2/7 [tensorboard]
#    ----------- ---------------------------- 2/7 [tensorboard]
#    ----------- ---------------------------- 2/7 [tensorboard]
#    ----------- ---------------------------- 2/7 [tensorboard]
#    ----------- ---------------------------- 2/7 [tensorboard]
#   Attempting uninstall: ml-dtypes
#    ----------- ---------------------------- 2/7 [tensorboard]
#     Found existing installation: ml_dtypes 0.5.1
#    ----------- ---------------------------- 2/7 [tensorboard]
#     Uninstalling ml_dtypes-0.5.1:
#    ----------- ---------------------------- 2/7 [tensorboard]
#       Successfully uninstalled ml_dtypes-0.5.1
#    ----------- ---------------------------- 2/7 [tensorboard]
#    ----------------- ---------------------- 3/7 [ml-dtypes]
#    ----------------- ---------------------- 3/7 [ml-dtypes]
#    ----------------- ---------------------- 3/7 [ml-dtypes]
#    ----------------- ---------------------- 3/7 [ml-dtypes]
#    ----------------- ---------------------- 3/7 [ml-dtypes]
#    ----------------- ---------------------- 3/7 [ml-dtypes]
#    ----------------- ---------------------- 3/7 [ml-dtypes]
#    ----------------- ---------------------- 3/7 [ml-dtypes]
#    ----------------- ---------------------- 3/7 [ml-dtypes]
#    ----------------- ---------------------- 3/7 [ml-dtypes]
#    ----------------- ---------------------- 3/7 [ml-dtypes]
#    ----------------- ---------------------- 3/7 [ml-dtypes]
#    ----------------- ---------------------- 3/7 [ml-dtypes]
#    ----------------- ---------------------- 3/7 [ml-dtypes]
#    ----------------- ---------------------- 3/7 [ml-dtypes]
#    ----------------- ---------------------- 3/7 [ml-dtypes]
#    ----------------- ---------------------- 3/7 [ml-dtypes]
#    ----------------- ---------------------- 3/7 [ml-dtypes]
#    ---------------------- ----------------- 4/7 [tensorflow-intel]
#    ---------------------- ----------------- 4/7 [tensorflow-intel]
#    ---------------------- ----------------- 4/7 [tensorflow-intel]
#
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\admin\OneDrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\Lib\site-packages\google\~upb'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\admin\OneDrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\Lib\site-packages\~umpy.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\admin\OneDrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\Lib\site-packages\~umpy'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\admin\OneDrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\Lib\site-packages\~l_dtypes'.
#   You can safely remove it manually.
# ERROR: Could not install packages due to an OSError: [WinError 5] 액세스가 거부되었습니다: 'c:\\Users\\admin\\OneDrive\\바탕 화면\\김문수2\\ai_class_source\\09 핀테크 머신러닝과 딥러닝 이해\\source\\.venv\\Lib\\site-packages\\tensorflow\\compiler\\mlir\\lite\\python\\_pywrap_converter_api.pyd'
# Check the permissions.

# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (2.19.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow) (2.3.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow) (4.25.8)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow) (2.32.4)
# Requirement already satisfied: setuptools in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow) (4.14.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow) (1.73.0)
# Requirement already satisfied: tensorboard~=2.19.0 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow) (3.10.0)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow) (0.5.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.6.15)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.8.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.1.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from keras>=3.5.0->tensorflow) (14.0.0)
# Requirement already satisfied: namex in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from keras>=3.5.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from keras>=3.5.0->tensorflow) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\admin\onedrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow
import tensorflow_hub as hub
import tf_keras as keras
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 import tensorflow
#       2 import tensorflow_hub as hub
#       3 import tf_keras as keras
#
# File c:\Users\admin\OneDrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\Lib\site-packages\tensorflow\__init__.py:47
#      44 from tensorflow.python import tf2 as _tf2
#      45 _tf2.enable()
# ---> 47 from tensorflow._api.v2 import __internal__
#      48 from tensorflow._api.v2 import __operators__
#      49 from tensorflow._api.v2 import audio
#
# File c:\Users\admin\OneDrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\Lib\site-packages\tensorflow\_api\v2\__internal__\__init__.py:13
#      11 from tensorflow._api.v2.__internal__ import distribute
#      12 from tensorflow._api.v2.__internal__ import eager_context
# ---> 13 from tensorflow._api.v2.__internal__ import feature_column
#      14 from tensorflow._api.v2.__internal__ import function
#      15 from tensorflow._api.v2.__internal__ import graph_util
#
# File c:\Users\admin\OneDrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\Lib\site-packages\tensorflow\_api\v2\__internal__\feature_column\__init__.py:8
#       3 """Public API for tf._api.v2.__internal__.feature_column namespace
#       4 """
#       6 import sys as _sys
# ----> 8 from tensorflow.python.feature_column.feature_column_v2 import DenseColumn # line: 1777
#       9 from tensorflow.python.feature_column.feature_column_v2 import FeatureTransformationCache # line: 1962
#      10 from tensorflow.python.feature_column.feature_column_v2 import SequenceDenseColumn # line: 1941
#
# File c:\Users\admin\OneDrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\Lib\site-packages\tensorflow\python\feature_column\feature_column_v2.py:38
#      36 from tensorflow.python.data.ops import readers
#      37 from tensorflow.python.eager import context
# ---> 38 from tensorflow.python.feature_column import feature_column as fc_old
#      39 from tensorflow.python.feature_column import feature_column_v2_types as fc_types
#      40 from tensorflow.python.feature_column import serialization
#
# File c:\Users\admin\OneDrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\Lib\site-packages\tensorflow\python\feature_column\feature_column.py:41
#      39 from tensorflow.python.framework import sparse_tensor as sparse_tensor_lib
#      40 from tensorflow.python.framework import tensor_shape
# ---> 41 from tensorflow.python.layers import base
#      42 from tensorflow.python.ops import array_ops
#      43 from tensorflow.python.ops import array_ops_stack
#
# File c:\Users\admin\OneDrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\Lib\site-packages\tensorflow\python\layers\base.py:16
#       1 # Copyright 2015 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)     13 # limitations under the License.
#      14 # =============================================================================
#      15 """Contains the base Layer class, from which all layers inherit."""
# ---> 16 from tensorflow.python.keras.legacy_tf_layers import base
#      18 InputSpec = base.InputSpec
#      20 keras_style_scope = base.keras_style_scope
#
# File c:\Users\admin\OneDrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\Lib\site-packages\tensorflow\python\keras\__init__.py:25
#      22 from tensorflow.python.keras import distribute
#      24 # See b/110718070#comment18 for more details about this import.
# ---> 25 from tensorflow.python.keras import models
#      27 from tensorflow.python.keras.engine.input_layer import Input
#      28 from tensorflow.python.keras.engine.sequential import Sequential
#
# File c:\Users\admin\OneDrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\Lib\site-packages\tensorflow\python\keras\models.py:25
#      23 from tensorflow.python.keras.engine import sequential
#      24 from tensorflow.python.keras.engine import training
# ---> 25 from tensorflow.python.keras.engine import training_v1
#      26 from tensorflow.python.keras.engine.base_layer import AddMetric
#      27 from tensorflow.python.keras.engine.base_layer import Layer
#
# File c:\Users\admin\OneDrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\Lib\site-packages\tensorflow\python\keras\engine\training_v1.py:46
#      44 from tensorflow.python.keras.engine import base_layer
#      45 from tensorflow.python.keras.engine import training as training_lib
# ---> 46 from tensorflow.python.keras.engine import training_arrays_v1
#      47 from tensorflow.python.keras.engine import training_distributed_v1
#      48 from tensorflow.python.keras.engine import training_eager_v1
#
# File c:\Users\admin\OneDrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\Lib\site-packages\tensorflow\python\keras\engine\training_arrays_v1.py:37
#      34 from tensorflow.python.util import nest
#      36 try:
# ---> 37   from scipy.sparse import issparse  # pylint: disable=g-import-not-at-top
#      38 except ImportError:
#      39   issparse = None
#
# File c:\Users\admin\OneDrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\Lib\site-packages\scipy\sparse\__init__.py:300
#     294 # Original code by Travis Oliphant.
#     295 # Modified and extended by Ed Schofield, Robert Cimrman,
#     296 # Nathan Bell, and Jake Vanderplas.
#     298 import warnings as _warnings
# --> 300 from ._base import *
#     301 from ._csr import *
#     302 from ._csc import *
#
# File c:\Users\admin\OneDrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\Lib\site-packages\scipy\sparse\_base.py:5
#       1 """Base class for sparse matrices"""
#       3 import numpy as np
# ----> 5 from ._sputils import (asmatrix, check_reshape_kwargs, check_shape,
#       6                        get_sum_dtype, isdense, isscalarlike,
#       7                        matrix, validateaxis, getdtype)
#       9 from ._matrix import spmatrix
#      11 __all__ = ['isspmatrix', 'issparse', 'sparray',
#      12            'SparseWarning', 'SparseEfficiencyWarning']
#
# File c:\Users\admin\OneDrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\Lib\site-packages\scipy\sparse\_sputils.py:10
#       8 from math import prod
#       9 import scipy.sparse as sp
# ---> 10 from scipy._lib._util import np_long, np_ulong
#      13 __all__ = ['upcast', 'getdtype', 'getdata', 'isscalarlike', 'isintlike',
#      14            'isshape', 'issequence', 'isdense', 'ismatrix', 'get_sum_dtype',
#      15            'broadcast_shapes']
#      17 supported_dtypes = [np.bool_, np.byte, np.ubyte, np.short, np.ushort, np.intc,
#      18                     np.uintc, np_long, np_ulong, np.longlong, np.ulonglong,
#      19                     np.float32, np.float64, np.longdouble,
#      20                     np.complex64, np.complex128, np.clongdouble]
#
# File c:\Users\admin\OneDrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\Lib\site-packages\scipy\_lib\_util.py:13
#      10 from typing import TypeAlias, TypeVar
#      12 import numpy as np
# ---> 13 from scipy._lib._array_api import array_namespace, is_numpy, xp_size
#      14 from scipy._lib._docscrape import FunctionDoc, Parameter
#      17 AxisError: type[Exception]
#
# File c:\Users\admin\OneDrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\Lib\site-packages\scipy\_lib\_array_api.py:18
#      15 import numpy.typing as npt
#      17 from scipy._lib import array_api_compat
# ---> 18 from scipy._lib.array_api_compat import (
#      19     is_array_api_obj,
#      20     size as xp_size,
#      21     numpy as np_compat,
#      22     device as xp_device,
#      23     is_numpy_namespace as is_numpy,
#      24     is_cupy_namespace as is_cupy,
#      25     is_torch_namespace as is_torch,
#      26     is_jax_namespace as is_jax,
#      27     is_array_api_strict_namespace as is_array_api_strict
#      28 )
#      30 __all__ = [
#      31     '_asarray', 'array_namespace', 'assert_almost_equal', 'assert_array_almost_equal',
#      32     'get_xp_devices',
#    (...)     38     'xp_take_along_axis', 'xp_unsupported_param_msg', 'xp_vector_norm',
#      39 ]
#      42 # To enable array API and strict array-like input validation
#
# File c:\Users\admin\OneDrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\Lib\site-packages\scipy\_lib\array_api_compat\numpy\__init__.py:1
# ----> 1 from numpy import * # noqa: F403
#       3 # from numpy import * doesn't overwrite these builtin names
#       4 from numpy import abs, max, min, round # noqa: F401
#
# File <frozen importlib._bootstrap>:1410, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File <frozen importlib._bootstrap>:1412, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File c:\Users\admin\OneDrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\Lib\site-packages\numpy\__init__.py:353, in __getattr__(attr)
#     350 def __dir__():
#     351     public_symbols = globals().keys() | {'testing'}
#     352     public_symbols -= {
# --> 353         "core", "matrixlib",
#     354         # These were moved in 1.25 and may be deprecated eventually:
#     355         "ModuleDeprecationWarning", "VisibleDeprecationWarning",
#     356         "ComplexWarning", "TooHardError", "AxisError"
#     357     }
#     358     return list(public_symbols)
#
# File c:\Users\admin\OneDrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\Lib\site-packages\numpy\random\__init__.py:180
#     126 __all__ = [
#     127     'beta',
#     128     'binomial',
#    (...)    176     'zipf',
#     177 ]
#     179 # add these for module-freeze analysis (like PyInstaller)
# --> 180 from . import _pickle
#     181 from . import _common
#     182 from . import _bounded_integers
#
# File c:\Users\admin\OneDrive\바탕 화면\김문수2\ai_class_source\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\Lib\site-packages\numpy\random\_pickle.py:1
# ----> 1 from .mtrand import RandomState
#       2 from ._philox import Philox
#       3 from ._pcg64 import PCG64, PCG64DXSM
#
# File numpy\\random\\mtrand.pyx:1, in init numpy.random.mtrand()
#
# ValueError: numpy.dtype size changed, may indicate binary incompatibility. Expected 96 from C header, got 88 from PyObject
